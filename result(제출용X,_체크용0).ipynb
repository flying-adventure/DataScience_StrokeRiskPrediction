# %%
import os
os.chdir('/content/drive/MyDrive/데이터')

# %%
# %run FinalMain.py
# Out:
# Completed Data Pre-processing: Remove data for individuals under 20 years old and those with a BMI over 80...
# One-hot Encoding of Categorical variables..
# Complete Feature (X) and Target (y) separation..
#
# [Feature Importance Analysis]
# Top 10 Feature Importances:
# age                               0.266315
# avg_glucose_level                 0.264813
# bmi                               0.231387
# Residence_type_Urban              0.040492
# gender_Male                       0.034542
# heart_disease                     0.025081
# hypertension                      0.024942
# work_type_Private                 0.021872
# smoking_status_never smoked       0.020212
# smoking_status_formerly smoked    0.018364
# dtype: float64
# Complete Feature Importance VIsualization ('feature_importances.png')..
#
# [Apply SMOTE]
# Class distribution before applying SMOTE:
#  stroke
# 0    3895
# 1     247
# Name: count, dtype: int64
# Class distribution after applying SMOTE:
#  stroke
# ...
